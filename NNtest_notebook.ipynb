# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn.metrics as metrics
from keras.layers.embeddings import Embedding
# Out:
# Using Theano backend.
# Using gpu device 0: Quadro K620 (CNMeM is disabled, CuDNN not available)

# %%
h = np.load('logs/recurrent19.py_hist.npy').item()
test_acc = h['test_acc']
print "Accuracy on corpus #%d test set = %f" % (h['corpus'],test_acc)
# Out:
# Accuracy on corpus #1 test set = 0.435028

# %%
plt.plot(h['acc'])
plt.plot(h['val_acc'])
plt.title('LSTM Accuracy')
plt.xlabel('epochs')
plt.legend(['training accuracy','validation accuracy'])
plt.figure()
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.title('LSTM Loss Function')
plt.xlabel('epochs')

# %%
h.item()
# Out:
# {'acc': [0.32339089481946626,
#   0.66718995290423866,
#   0.93092621664050235,
#   0.98744113029827318,
#   0.9952904238618524,
#   0.9952904238618524,
#   0.99686028257456827,
#   0.99686028257456827,
#   0.99843014128728413,
#   0.99843014128728413],
#  'corpus': 1,
#  'loss': [1.4899739326450103,
#   0.8471956336856169,
#   0.21113869022430701,
#   0.055962227449571099,
#   0.015570497135216885,
#   0.023910097871071678,
#   0.0090685298212118924,
#   0.0050570852446975298,
#   0.0058403717735510874,
#   0.0056805832354481448],
#  'test_acc': 0.43502824858757061,
#  'test_loss': 2.560354849444074,
#  'val_acc': [0.38028169014084506,
#   0.45070422535211269,
#   0.53521126760563376,
#   0.52112676056338025,
#   0.49295774647887325,
#   0.45070422535211269,
#   0.46478873239436619,
#   0.49295774647887325,
#   0.47887323943661969,
#   0.50704225352112675],
#  'val_loss': [1.4200852924669292,
#   1.2851068533852066,
#   1.7102298456322873,
#   1.7233933356244602,
#   1.9324722650205113,
#   1.9296621324885539,
#   2.0005784722743556,
#   2.0340519198111968,
#   2.0958065130220298,
#   2.0212269627717063]}
